# %% [markdown]
# # DLC_PIPELINE

# %% [markdown]
# Created 03/24/25

# %% [markdown]
# ## BACKGROUND

# %% [markdown]
# This notebook interfaces with the Lake Lab DLC_FILTER_PIPELINE for testing purposes. It reads in a list of videos, and lets the user apply a preconfigured DLC pipeline to it along with custom filtering

# %% [markdown]
# # IMPORTS

# %%
import dlcfilterpipeline as dlp

# %% [markdown]
# # PIPELINE

# %%
pipe = dlp.manager(#"/Users/paveyboys/Desktop/EXAMPLE/20250303_4421_01.avi",
                    defaultdir =
                    "/Users/paveyboys/Desktop/EXAMPLE/", #"/Volumes/lake.s/Active/Shawn P/AAA. DEEPLABCUT/TEST20250303/",
                    save_files=True,
                    model_name='DLC_Resnet50_Cropped_HiResMar14shuffle0_snapshot_190',
                    analyze_videos = True,
                    create_videos = True,
                    animate = False,
                    graph_video_frame_step = 1,
                    cluster_trim_percent = 5
                   )
# Out:
# 2025-04-07 11:22:34.028 python[60433:12333214] +[CATransaction synchronize] called within transaction
# Selected file:  /Volumes/lake.s/Active/Shawn P/D. DATA (PROCESSED)/A. ELASTIN PROJECT/GAIT/20250320/AVI/20250320_4491_02.avi
# Selected file:  /Volumes/lake.s/Active/Shawn P/D. DATA (PROCESSED)/A. ELASTIN PROJECT/GAIT/20250320/AVI/20250320_4491_03.avi
# Selected file:  /Volumes/lake.s/Active/Shawn P/D. DATA (PROCESSED)/A. ELASTIN PROJECT/GAIT/20250320/AVI/20250320_4491_04.avi
# Selected file:  /Volumes/lake.s/Active/Shawn P/D. DATA (PROCESSED)/A. ELASTIN PROJECT/GAIT/20250320/AVI/20250320_4491_05.avi
# Selected file:  /Volumes/lake.s/Active/Shawn P/D. DATA (PROCESSED)/A. ELASTIN PROJECT/GAIT/20250320/AVI/20250320_4491_06.avi
# Selected file:  /Volumes/lake.s/Active/Shawn P/D. DATA (PROCESSED)/A. ELASTIN PROJECT/GAIT/20250320/AVI/20250320_4491_07.avi
# Selected file:  /Volumes/lake.s/Active/Shawn P/D. DATA (PROCESSED)/A. ELASTIN PROJECT/GAIT/20250320/AVI/20250320_4491_08.avi
# ...

# %%
#pipe.single_process("/Volumes/lake.s/Active/Shawn P/AAA. DEEPLABCUT/TEST20250303/20250303_4421_01.avi")
pipe.batch_process()
# Out:
# Processing /Volumes/lake.s/Active/Shawn P/D. DATA (PROCESSED)/A. ELASTIN PROJECT/GAIT/20250320/AVI/20250320_4491_02.avi
# Loading DLC 3.0.0rc6...
# DLC loaded in light mode; you cannot use any GUI (labeling, relabeling and standalone GUI)
# Analyzing videos with /Users/paveyboys/PycharmProjects/DLC_FILTER_PIPELINE/dlcfilterpipeline/dlc-models-pytorch/iteration-0/Cropped_HiResMar14-trainset95shuffle0/train/snapshot-best-190.pt
# Starting to analyze /Volumes/lake.s/Active/Shawn P/D. DATA (PROCESSED)/A. ELASTIN PROJECT/GAIT/20250320/AVI/20250320_4491_02.avi
# Video metadata:
#   Overall # of frames:    919
#   Duration of video [s]:  30.63
#   fps:                    30.0
#   resolution:             w=1280, h=300
#
# Running pose prediction with batch size 8
# 100%|██████████| 919/919 [02:22<00:00,  6.45it/s]
# ...

# %%
# import pandas as pd
# import numpy as np
#
# def between_fill(df,col_name):
#     forward_fill_df = df[[col_name]].copy().replace(-1,np.nan).ffill()
#     back_fill_df = df[[col_name]].copy().replace(-1, np.nan).bfill()
#     mask = forward_fill_df == back_fill_df
#     result = pd.DataFrame(-1, index=forward_fill_df.index, columns=forward_fill_df.columns)
#     result[mask] = forward_fill_df[mask]
#     df[col_name] = result
#     return df
#
# df = pd.DataFrame({'col_name': [1, -1 ,-1, 2,-1,-1,-1,2, 3, 4],'other_col_name': [1, -1 ,-1, 2,-1,3,-1,2, 3, 4]})
# output = between_fill(df, 'col_name')
# print(output)
